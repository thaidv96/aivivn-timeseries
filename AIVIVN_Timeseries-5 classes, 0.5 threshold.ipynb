# %%
# !curl -s https://course.fast.ai/setup/colab | bash
    
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.tabular import *


from google.colab import drive

drive.mount("/content/drive")
path = Path('/content/drive/My Drive/Competitions/Timeseries')
# Out:
# Updating fastai...
# Done.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/Competitions/Timeseries/models/aivivn_timeseries.zip' -d '/content/drive/My Drive/Competitions/Timeseries/datasets'

# %%
tet_holidays = {'2018':{'start':'2018-02-11', 
                        'end':'2018-02-24'},
                '2019':{'start':'2019-01-31',
                        'end':'2019-02-14'
                       }
               }

# %%
def prepare_data(path, is_train = True):
    df = pd.read_csv(path)
    if is_train:
        df = df[(df.MAX_USER != 0)]
        df['MAX_USER'] = df['MAX_USER']/51
#         df.BANDWIDTH_TOTAL = 1/df.BANDWIDTH_TOTAL**2
    num_active_server = df.groupby(['UPDATE_TIME','HOUR_ID']).SERVER_NAME.nunique().reset_index()
    num_active_server.columns = ['UPDATE_TIME','HOUR_ID','NUM_ACTIVE_SERVER']
    num_active_zone = df.groupby(['UPDATE_TIME','HOUR_ID']).ZONE_CODE.nunique().reset_index()
    num_active_zone.columns = ['UPDATE_TIME','HOUR_ID','NUM_ACTIVE_ZONE']    
    df = pd.merge(df, num_active_server, on = ['UPDATE_TIME','HOUR_ID'])
    df = pd.merge(df, num_active_zone, on = ['UPDATE_TIME','HOUR_ID'])
    df = add_datepart(df, 'UPDATE_TIME', drop= False)
    df['IS_TET'] = (((pd.to_datetime(df.UPDATE_TIME) > pd.to_datetime(tet_holidays['2018']['start'])) 
                   &(pd.to_datetime(df.UPDATE_TIME) < pd.to_datetime(tet_holidays['2018']['end'])))
                   |((pd.to_datetime(df.UPDATE_TIME) > pd.to_datetime(tet_holidays['2019']['start'])) 
                   &(pd.to_datetime(df.UPDATE_TIME) < pd.to_datetime(tet_holidays['2019']['end'])))
                  )
    df = df[df.IS_TET == False]
    df.reset_index(inplace=True)
    del df['index']
    return df

# %%
train = prepare_data(path/'datasets/train.csv')

# %%
test = [1,2,3,4,5]
test.reverse()

# %%
bandwidth_total = train[train.BANDWIDTH_TOTAL>0].BANDWIDTH_TOTAL

# %%
def encode_range(value):
    global threshold
    for i in range(len(threshold)):
        if value >= threshold[i]:
            return i
encode_range = np.vectorize(encode_range)

# %%
threshold = []
def target_encode(df, target_col, num_classes):
    ## Gen threshold:
    global threshold
    threshold= []
    step_size = 100/num_classes
    for i in range(num_classes):
        t = np.percentile(df[target_col],(i)*step_size)
        threshold = [t] + threshold
    df['target_encoded'] = encode_range(df[target_col])
    return df

# %%
train = target_encode(train, 'BANDWIDTH_TOTAL', 5)

# %%
test_df.head()
# Out:
#      id UPDATE_TIME  ...  UPDATE_TIMEElapsed IS_TET
# 0     0  2019-03-10  ...          1552176000  False
# 1   743  2019-03-10  ...          1552176000  False
# 2  1486  2019-03-10  ...          1552176000  False
# 3  2229  2019-03-10  ...          1552176000  False
# 4  2972  2019-03-10  ...          1552176000  False
#
# [5 rows x 21 columns]

# %%
cont_vars = ['NUM_ACTIVE_SERVER', 'NUM_ACTIVE_ZONE','UPDATE_TIMEElapsed']
cat_vars = ['HOUR_ID', 'ZONE_CODE','SERVER_NAME','UPDATE_TIMEYear', 'IS_TET','UPDATE_TIMEMonth','UPDATE_TIMEWeek','UPDATE_TIMEDay','UPDATE_TIMEDayofweek']
dep_var = 'target_encoded'

procs=[FillMissing, Categorify, Normalize]

# %%
cut_idx = min(train[train.UPDATE_TIME > '2019-01-09'].index )

valid_idx = range(cut_idx, train.shape[0])

# %%
test_df = prepare_data(path/'datasets/test_id.csv', is_train = False)

# %%
test_df.head()
# Out:
#      id UPDATE_TIME  ...  UPDATE_TIMEElapsed IS_TET
# 0     0  2019-03-10  ...          1552176000  False
# 1   743  2019-03-10  ...          1552176000  False
# 2  1486  2019-03-10  ...          1552176000  False
# 3  2229  2019-03-10  ...          1552176000  False
# 4  2972  2019-03-10  ...          1552176000  False
#
# [5 rows x 21 columns]

# %%
train['NUM_ACTIVE_SERVER']
# Out:
# 0          313
# 1          313
# 2          313
# 3          313
# 4          313
# 5          313
# 6          313
# 7          313
# 8          313
# 9          313
# 10         313
# 11         313
# 12         313
# 13         313
# 14         313
# 15         313
# 16         313
# 17         313
# 18         313
# 19         313
# 20         313
# 21         313
# 22         313
# 23         313
# 24         313
# 25         313
# 26         313
# 27         313
# 28         313
# 29         313
#           ...
# 5915052    499
# 5915053    499
# 5915054    499
# 5915055    499
# 5915056    499
# 5915057    499
# 5915058    499
# 5915059    499
# 5915060    499
# 5915061    499
# 5915062    499
# 5915063    499
# 5915064    499
# 5915065    499
# 5915066    499
# 5915067    499
# 5915068    499
# 5915069    499
# 5915070    499
# 5915071    499
# 5915072    499
# 5915073    499
# 5915074    499
# 5915075    499
# 5915076    499
# 5915077    499
# 5915078    499
# 5915079    499
# 5915080    499
# 5915081    499
# Name: NUM_ACTIVE_SERVER, Length: 5915082, dtype: int64

# %%
def inverse_exp_mape(pred:Tensor, targ:Tensor)->Rank0Tensor:
    "Exp MAPE between `pred` and `targ`."
    pred,targ = flatten_check(pred,targ)
    pred, targ = torch.exp(pred), torch.exp(targ)
    pct_var = torch.abs(torch.sqrt(1/targ) - torch.sqrt(1/pred))*torch.sqrt(targ)
    return pct_var.mean()*100

# %%
def exp_mape(pred:Tensor, targ:Tensor)->Rank0Tensor:
    "Exp MAPE between `pred` and `targ`."
    pred,targ = flatten_check(pred,targ)
    pred, targ = torch.exp(pred), torch.exp(targ)
    pct_var = torch.abs(targ - pred)/targ
    return pct_var.mean()*100

# %%
def mape(pred:Tensor, targ:Tensor)->Rank0Tensor:
    "Exp MAPE between `pred` and `targ`."
    pred,targ = flatten_check(pred,targ)
    pct_var = torch.abs(targ - pred)/targ
    return pct_var.mean()*100

# %%
data = (TabularList.from_df(train, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var)
                .add_test(TabularList.from_df(test_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=accuracy)

# %%
def weighted_mse(inp, target):
    return torch.mean((inp-target)**2/torch.exp(target)**2)

# %%
learn.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.967592</td>
#       <td>1.072006</td>
#       <td>0.572519</td>
#       <td>23:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
dep_var2 = 'MAX_USER'
data2 = (TabularList.from_df(train, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var2, label_cls=FloatList, log=True)
                .add_test(TabularList.from_df(test_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

max_log_y2 = np.log(np.max(train['MAX_USER'])*1.2)
y_range2 = torch.tensor([0, max_log_y2], device=defaults.device)

learn2 = tabular_learner(data2, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range2, metrics=exp_mape)

# %%
learn2.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.fit_one_cycle(1, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>exp_mape</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.069218</td>
#       <td>0.136755</td>
#       <td>25.241941</td>
#       <td>27:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
max_user_preds=learn2.get_preds(DatasetType.Test)

# %%
bandwidth_total_preds = learn.get_preds(DatasetType.Test)

# %%
interpret = learn.interpret()

# %%
bandwidth_total_preds[1]
# Out:
# tensor([0, 0, 0,  ..., 0, 0, 0])

# %%
temp = [max(i) for i in bandwidth_total_preds[0].numpy()]

# %%
interpret.confusion_matrix()
# Out:
# array([[169105,  20820,   3308,   2859,    828],
#        [ 37972,  43838,  17675,  17459,   5630],
#        [  7520,  17922,  22667,  30967,  15642],
#        [  2298,   2875,  10098,  28212,  30890],
#        [   786,    203,   1157,   9594,  52923]])

# %%
test_df['prob'] =  temp

# %%
test_df['adj_bandwidth_total'] = test_df['BANDWIDTH_TOTAL']

# %%
def adj_bandwidth(value, prob):
    if prob < 0.5:
        return 0
    return value

adj_bandwidth = np.vectorize(adj_bandwidth)

# %%
test_df['adj_bandwidth_total']= adj_bandwidth(test_df['BANDWIDTH_TOTAL'], test_df['prob'])

# %%
test_df.BANDWIDTH_TOTAL = test_df.BANDWIDTH_TOTAL.map(lambda i: threshold[int(i)])

# %%
test_df['MAX_USER'] = (np.exp(max_user_preds[0].data).numpy()*51).T[0].astype(int)

# %%
test_df['BANDWIDTH_TOTAL'] = np.round(test_df['BANDWIDTH_TOTAL']/10, 2)

# %%
valid_df = train.iloc[valid_idx]

# %%
valid_df['pred_bandwidth']

# %%
def convert_to_label(x1, x2):
    return '{:.2f} {}'.format(x1, int(x2))

convert_to_label = np.vectorize(convert_to_label)

# %%
test_df.head()
# Out:
#      id UPDATE_TIME  HOUR_ID  ... MAX_USER BANDWIDTH_TOTAL      label
# 0     0  2019-03-10        0  ...     1316        1.000005  0.00 1316
# 1   743  2019-03-10        0  ...     2215        1.000003  0.00 2215
# 2  1486  2019-03-10        0  ...     3106        1.000009  0.00 3106
# 3  2229  2019-03-10        0  ...     2253        1.000001  0.00 2253
# 4  2972  2019-03-10        0  ...     1804        1.000000  0.00 1804
#
# [5 rows x 24 columns]

# %%
test_df['label'] = convert_to_label(test_df.adj_bandwidth_total, test_df.MAX_USER)

# %%
test_df[['id','label']].to_csv(path/'submission.csv', index = False)

# %%
test_df[test_df.prob>0.5].head(100)
# Out:
#           id UPDATE_TIME  HOUR_ID  ...        label      prob  adj_bandwidth_total
# 3       2229  2019-03-10        0  ...  146.00 1148  0.580483                  146
# 4       2972  2019-03-10        0  ...   146.00 929  0.661359                  146
# 5       3715  2019-03-10        0  ...   146.00 381  0.855121                  146
# 6       5944  2019-03-10        0  ...  146.00 1499  0.650109                  146
# 7       6687  2019-03-10        0  ...  146.00 1669  0.695723                  146
# 9       9659  2019-03-10        0  ...  146.00 1828  0.538528                  146
# 10     10402  2019-03-10        0  ...  146.00 6547  0.504415                  146
# 13     14114  2019-03-10        0  ...  146.00 1673  0.502998                  146
# 15     15598  2019-03-10        0  ...  146.00 1910  0.571960                  146
# 29     26000  2019-03-10        0  ...  146.00 1833  0.597187                  146
# 35     30458  2019-03-10        0  ...  146.00 3819  0.503489                  146
# 36     31201  2019-03-10        0  ...  146.00 2374  0.587440                  146
# 38     32687  2019-03-10        0  ...  146.00 2607  0.551472                  146
# 40     34173  2019-03-10        0  ...  146.00 4697  0.585525                  146
# 43     36402  2019-03-10        0  ...  146.00 6080  0.503837                  146
# 75     60920  2019-03-10        0  ...  146.00 3222  0.511372                  146
# 78     63149  2019-03-10        0  ...  146.00 1194  0.540862                  146
# 86     69079  2019-03-10        0  ...  146.00 1491  0.685069                  146
# 97     77224  2019-03-10        0  ...  146.00 1648  0.507855                  146
# 99     78710  2019-03-10        0  ...  146.00 2314  0.504113                  146
# 101    80196  2019-03-10        0  ...  146.00 2647  0.507374                  146
# 102    80939  2019-03-10        0  ...  146.00 3143  0.504127                  146
# 103    81682  2019-03-10        0  ...  146.00 2308  0.573572                  146
# 106    83911  2019-03-10        0  ...  146.00 3222  0.560752                  146
# 107    84654  2019-03-10        0  ...  146.00 3558  0.528411                  146
# 117    92084  2019-03-10        0  ...  146.00 3019  0.606135                  146
# 119    93570  2019-03-10        0  ...  146.00 2428  0.520109                  146
# 123    96542  2019-03-10        0  ...  146.00 1280  0.665211                  146
# 126    98771  2019-03-10        0  ...  146.00 2871  0.570458                  146
# 127    99514  2019-03-10        0  ...  146.00 2758  0.568369                  146
# ...      ...         ...      ...  ...          ...       ...                  ...
# 680   142905  2019-03-10        1  ...   146.00 915  0.544723                  146
# 708   163709  2019-03-10        1  ...  146.00 1720  0.560497                  146
# 773   212004  2019-03-10        1  ...  146.00 3085  0.649761                  146
# 776   214233  2019-03-10        1  ...  146.00 1078  0.611594                  146
# 793   226863  2019-03-10        1  ...  146.00 6147  0.544646                  146
# 800   234291  2019-03-10        1  ...   146.00 426  0.508596                  146
# 1002    2974  2019-03-10        2  ...   146.00 579  0.690343                  146
# 1292  226864  2019-03-10        2  ...  146.00 4880  0.580002                  146
# 1791  226865  2019-03-10        3  ...  146.00 4115  0.602529                  146
# 2006   10406  2019-03-10        4  ...  146.00 3825  0.542268                  146
# 2290  226866  2019-03-10        4  ...  146.00 4067  0.677556                  146
# 2498    2234  2019-03-10        5  ...   146.00 823  0.571871                  146
# 2499    2977  2019-03-10        5  ...   146.00 738  0.779822                  146
# 2505   10407  2019-03-10        5  ...  146.00 4860  0.556164                  146
# 2529   29720  2019-03-10        5  ...  146.00 2768  0.516319                  146
# 2530   30463  2019-03-10        5  ...  146.00 2313  0.559483                  146
# 2534   33435  2019-03-10        5  ...  146.00 2706  0.523347                  146
# 2538   36407  2019-03-10        5  ...  146.00 3113  0.546847                  146
# 2582   69813  2019-03-10        5  ...  146.00 2235  0.541450                  146
# 2596   80201  2019-03-10        5  ...  146.00 1785  0.536043                  146
# 2597   80944  2019-03-10        5  ...  146.00 1743  0.584000                  146
# 2655  124781  2019-03-10        5  ...  146.00 2789  0.523845                  146
# 2658  127010  2019-03-10        5  ...  146.00 1964  0.518803                  146
# 2704  163713  2019-03-10        5  ...  146.00 1392  0.654177                  146
# 2714  171143  2019-03-10        5  ...      0.00 65  0.694237                    0
# 2772  214237  2019-03-10        5  ...  146.00 1598  0.663466                  146
# 2780  220181  2019-03-10        5  ...  146.00 2034  0.517648                  146
# 2788  226125  2019-03-10        5  ...  146.00 2556  0.561633                  146
# 2789  226867  2019-03-10        5  ...  146.00 5801  0.648531                  146
# 2810  250683  2019-03-10        5  ...  146.00 2990  0.583442                  146
#
# [100 rows x 26 columns]

# %%
test_df.shape
# Out:
# (390579, 24)

# %%
test = pd.read_csv(path/'datasets/test_id.csv')

# %%
test.shape
# Out:
# (371619, 5)

# %%
bandwidth_baseline = train.groupby(['SERVER_NAME']).BANDWIDTH_TOTAL.min().reset_index()
max_user_baseline = train.groupby(['SERVER_NAME']).MAX_USER.min().reset_index()

# %%
test_baseline = pd.merge(test[['id','SERVER_NAME','ZONE_CODE','HOUR_ID','UPDATE_TIME']], bandwidth_baseline, on = ['SERVER_NAME'], how = 'left')

# %%
test_baseline = pd.merge(test_baseline, max_user_baseline, on = ['SERVER_NAME'], how = 'left')

# %%
test_baseline.fillna(0, inplace = True)

# %%
test_baseline['label'] = convert_to_label(test_baseline.BANDWIDTH_TOTAL, test_baseline.MAX_USER)

# %%
train[train.SERVER_NAME=='SERVER_ZONE03_057']
# Out:
#         UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 5751217  2019-02-23       21    ZONE03  SERVER_ZONE03_057       218.279387
#
#          MAX_USER  NUM_ACTIVE_SERVER  NUM_ACTIVE_ZONE  UPDATE_TIMEYear  \
# 5751217      33.0                471                3             2019
#
#          UPDATE_TIMEMonth  ...  UPDATE_TIMEDayofweek  UPDATE_TIMEDayofyear  \
# 5751217                 2  ...                     5                    54
#
#          UPDATE_TIMEIs_month_end  UPDATE_TIMEIs_month_start  \
# 5751217                    False                      False
#
#          UPDATE_TIMEIs_quarter_end  UPDATE_TIMEIs_quarter_start  \
# 5751217                      False                        False
#
#          UPDATE_TIMEIs_year_end  UPDATE_TIMEIs_year_start  UPDATE_TIMEElapsed  \
# 5751217                   False                     False          1550880000
#
#          IS_TET
# 5751217   False
#
# [1 rows x 22 columns]

# %%
test_baseline[['id','label']].to_csv(path/'submission.csv', index = False)

# %%
temp = pd.merge(test_df, test_baseline, on = 'id')

# %%
temp['diff'] = np.abs(temp.BANDWIDTH_TOTAL_x - temp.BANDWIDTH_TOTAL_y)/temp.BANDWIDTH_TOTAL_y*100

# %%
temp[temp.BANDWIDTH_TOTAL_y != 0]['diff'].mean()
# Out:
# 204.492663929818

# %%
train_df = train.iloc[:cut_idx]

# %%
valid_df = train.iloc[cut_idx:]

# %%
bandwidth_baseline = train_df.groupby(['SERVER_NAME','HOUR_ID']).BANDWIDTH_TOTAL.min().reset_index()
max_user_baseline = train_df.groupby(['SERVER_NAME','HOUR_ID']).MAX_USER.min().reset_index()

valid_baseline = pd.merge(valid_df[['SERVER_NAME','ZONE_CODE','HOUR_ID','UPDATE_TIME','BANDWIDTH_TOTAL','MAX_USER']], bandwidth_baseline, on = ['SERVER_NAME','HOUR_ID'], how = 'left')
valid_baseline = pd.merge(valid_baseline, max_user_baseline, on = ['SERVER_NAME','HOUR_ID'], how = 'left')

# %%
valid_baseline.head()
# Out:
#          SERVER_NAME ZONE_CODE  HOUR_ID UPDATE_TIME  BANDWIDTH_TOTAL_x  \
# 0  SERVER_ZONE01_001    ZONE01        0  2019-01-10          49.899507
# 1  SERVER_ZONE01_002    ZONE01        0  2019-01-10         125.708389
# 2  SERVER_ZONE01_003    ZONE01        0  2019-01-10         323.034620
# 3  SERVER_ZONE01_004    ZONE01        0  2019-01-10         161.477881
# 4  SERVER_ZONE01_005    ZONE01        0  2019-01-10         348.798064
#
#    MAX_USER_x  BANDWIDTH_TOTAL_y  MAX_USER_y
# 0        36.0           0.212989         6.0
# 1        25.0           1.967857         9.0
# 2        32.0           5.165978         9.0
# 3        44.0           9.943715         9.0
# 4        58.0          38.440665        12.0

# %%
small_mape = valid_baseline[valid_baseline.BANDWIDTH_TOTAL_y > 350]

np.mean(np.abs(small_mape['BANDWIDTH_TOTAL_y'] -small_mape['BANDWIDTH_TOTAL_x'])/small_mape['BANDWIDTH_TOTAL_x'])
# Out:
# 0.8276853667538071

# %%
iplot(train[train.SERVER_NAME == 'SERVER_ZONE01_106'].groupby("UPDATE_TIME").BANDWIDTH_TOTAL.sum().iplot(asFigure = True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-291-0c5db9f97f84> in <module>()
# ----> 1 iplot(train[train.SERVER_NAME == 'SERVER_ZONE01_106'].groupby("UPDATE_TIME").BANDWIDTH_TOTAL.sum().iplot(asFigure = True))
#
# NameError: name 'iplot' is not defined

# %%
set(train.SERVER_NAME).difference(test_df.SERVER_NAME)
# Out:
# {'SERVER_ZONE01_014',
#  'SERVER_ZONE01_015',
#  'SERVER_ZONE01_016',
#  'SERVER_ZONE01_046',
#  'SERVER_ZONE01_047',
#  'SERVER_ZONE01_048',
#  'SERVER_ZONE01_069',
#  'SERVER_ZONE01_070',
#  'SERVER_ZONE01_071',
#  'SERVER_ZONE01_093',
#  'SERVER_ZONE01_094',
#  'SERVER_ZONE01_095',
#  'SERVER_ZONE01_105',
#  'SERVER_ZONE01_106',
#  'SERVER_ZONE01_107',
#  'SERVER_ZONE01_108',
#  'SERVER_ZONE01_109',
#  'SERVER_ZONE01_110',
#  'SERVER_ZONE01_111',
#  'SERVER_ZONE01_168',
#  'SERVER_ZONE01_335',
#  'SERVER_ZONE01_336',
#  'SERVER_ZONE02_011',
#  'SERVER_ZONE02_012',
#  'SERVER_ZONE02_013',
#  'SERVER_ZONE02_083',
#  'SERVER_ZONE02_085',
#  'SERVER_ZONE02_101',
#  'SERVER_ZONE02_102',
#  'SERVER_ZONE02_103',
#  'SERVER_ZONE02_107',
#  'SERVER_ZONE02_108',
#  'SERVER_ZONE02_109',
#  'SERVER_ZONE02_110',
#  'SERVER_ZONE02_111',
#  'SERVER_ZONE02_112',
#  'SERVER_ZONE02_116',
#  'SERVER_ZONE02_117',
#  'SERVER_ZONE02_118',
#  'SERVER_ZONE02_137',
#  'SERVER_ZONE02_138',
#  'SERVER_ZONE02_139'}

# %%
set(test_df.SERVER_NAME).difference(train.SERVER_NAME)
# Out:
# set()

# %%
set(train.SERVER_NAME.value_counts())
# Out:
# {1,
#  2,
#  9,
#  184,
#  377,
#  488,
#  492,
#  972,
#  1103,
#  1720,
#  3461,
#  3464,
#  4006,
#  4009,
#  4010,
#  5670,
#  5717,
#  5718,
#  5721,
#  5732,
#  5735,
#  5739,
#  5741,
#  5742,
#  6236,
#  6238,
#  6354,
#  6355,
#  6356,
#  6452,
#  6546,
#  6584,
#  7855,
#  7856,
#  7858,
#  8256,
#  9186,
#  10302,
#  10303,
#  10304,
#  10305,
#  10306,
#  10307,
#  10308,
#  10309,
#  10310,
#  10311,
#  10312,
#  10313,
#  10314,
#  10325,
#  10330,
#  10371,
#  10453,
#  11057,
#  11059,
#  11060,
#  11327,
#  11330,
#  11357,
#  11360,
#  11379,
#  11380,
#  11381,
#  11432,
#  11433,
#  11435,
#  11436,
#  11437,
#  11438,
#  11439,
#  11440,
#  11441,
#  11442,
#  12138,
#  12139,
#  12142,
#  12191,
#  12192,
#  12193,
#  12194,
#  12196,
#  12197,
#  12199,
#  12212,
#  12220,
#  12226,
#  12227,
#  12229,
#  12233,
#  12235,
#  12236,
#  12243,
#  12244,
#  12254,
#  12257,
#  12258,
#  12259,
#  12260,
#  12261,
#  12262,
#  12263,
#  12264,
#  12265,
#  12266,
#  12267,
#  12268,
#  12269,
#  12270,
#  12271,
#  12272,
#  12273,
#  12274,
#  12275,
#  12276,
#  12277,
#  12278,
#  12279}

# %%
(valid_baseline.BANDWIDTH_TOTAL_y < 20).sum()
# Out:
# 180038

# %%
(180038*1 + 370749*0.8905040575809736)/(370749+180038)
# Out:
# 0.9262954442354093

# %%
small_mape = valid_baseline[valid_baseline.BANDWIDTH_TOTAL_y > 20]

np.mean(np.abs(small_mape['BANDWIDTH_TOTAL_y'] -small_mape['BANDWIDTH_TOTAL_x'] )/small_mape['BANDWIDTH_TOTAL_x'])

# %%
bandwidth_baseline = train_df.groupby(['SERVER_NAME','HOUR_ID']).BANDWIDTH_TOTAL.median().reset_index()
max_user_baseline = train_df.groupby(['SERVER_NAME','HOUR_ID']).MAX_USER.median().reset_index()

valid_baseline = pd.merge(valid_df[['SERVER_NAME','ZONE_CODE','HOUR_ID','UPDATE_TIME','BANDWIDTH_TOTAL','MAX_USER']], bandwidth_baseline, on = ['SERVER_NAME','HOUR_ID'], how = 'left')

# %%
valid_baseline.head()
# Out:
#          SERVER_NAME ZONE_CODE  HOUR_ID UPDATE_TIME  BANDWIDTH_TOTAL_x  \
# 0  SERVER_ZONE01_001    ZONE01        0  2019-01-10          49.899507
# 1  SERVER_ZONE01_002    ZONE01        0  2019-01-10         125.708389
# 2  SERVER_ZONE01_003    ZONE01        0  2019-01-10         323.034620
# 3  SERVER_ZONE01_004    ZONE01        0  2019-01-10         161.477881
# 4  SERVER_ZONE01_005    ZONE01        0  2019-01-10         348.798064
#
#    MAX_USER  BANDWIDTH_TOTAL_y
# 0      36.0          23.097169
# 1      25.0          52.762554
# 2      32.0          78.538994
# 3      44.0         129.556035
# 4      58.0         195.228154
