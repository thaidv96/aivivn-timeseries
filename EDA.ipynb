# %%
import pandas as pd
import plotly.graph_objs as go
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv("./datasets/train.csv")

test = pd.read_csv("./datasets/test_id.csv")

# %%
data['UPDATE_TIME'] = pd.to_datetime(data.UPDATE_TIME)

# %%
data['month'] = data.UPDATE_TIME.dt.strftime("%Y-%m")

# %%
data.head().T
# Out:
#                                    0                    1  \
# UPDATE_TIME      2017-10-01 00:00:00  2017-10-01 00:00:00
# HOUR_ID                            0                    0
# ZONE_CODE                     ZONE01               ZONE01
# SERVER_NAME        SERVER_ZONE01_001    SERVER_ZONE01_002
# BANDWIDTH_TOTAL              26.9069              61.4817
# MAX_USER                         612                  561
# month                        2017-10              2017-10
#
#                                    2                    3                    4
# UPDATE_TIME      2017-10-01 00:00:00  2017-10-01 00:00:00  2017-10-01 00:00:00
# HOUR_ID                            0                    0                    0
# ZONE_CODE                     ZONE01               ZONE01               ZONE01
# SERVER_NAME        SERVER_ZONE01_003    SERVER_ZONE01_004    SERVER_ZONE01_005
# BANDWIDTH_TOTAL              20.6098              97.7374              113.251
# ...

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
iplot(data.iplot(kind = 'box', asFigure = True, x= 'month', y = 'BANDWIDTH_TOTAL'))

# %%
bandwidth = data.BANDWIDTH_TOTAL

# %%
bandwidth = sorted(bandwidth)

# %%
import matplotlib.pyplot as plt

# %%
def label_encoding()
# Out:
# 43.82616272727273

# %%
import numpy as np

# %%
redundancies = set(data.SERVER_NAME).difference(test.SERVER_NAME)

# %%
import numpy as np

# %%
def is_redundant(val):
    return val in redundancies

is_redundant = np.vectorize(is_redundant)

# %%
data['is_redundant'] = is_redundant(data.SERVER_NAME)

# %%
data = data[data.is_redundant == False]

# %%
data.head()
# Out:
#   UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 0  2017-10-01        0    ZONE01  SERVER_ZONE01_001        26.906932
# 1  2017-10-01        0    ZONE01  SERVER_ZONE01_002        61.481693
# 2  2017-10-01        0    ZONE01  SERVER_ZONE01_003        20.609837
# 3  2017-10-01        0    ZONE01  SERVER_ZONE01_004        97.737384
# 4  2017-10-01        0    ZONE01  SERVER_ZONE01_005       113.250685
#
#    MAX_USER  is_redundant
# 0     612.0         False
# 1     561.0         False
# 2     969.0         False
# 3    1377.0         False
# 4    1887.0         False

# %%
mean = last_month_data.groupby('SERVER_NAME').BANDWIDTH_TOTAL.mean().reset_index()
median = last_month_data.groupby('SERVER_NAME').BANDWIDTH_TOTAL.median().reset_index()

# %%
last_month_data = data[data.UPDATE_TIME > '2019-01-09']

# %%
minimum = data.groupby('SERVER_NAME').BANDWIDTH_TOTAL.min().reset_index()
maximum = data.groupby('SERVER_NAME').BANDWIDTH_TOTAL.max().reset_index()

# %%
minimum = minimum.sort_values(by = "BANDWIDTH_TOTAL").reset_index()
maximum= maximum.sort_values(by ='BANDWIDTH_TOTAL').reset_index()

# %%
mean = mean.sort_values(by = "BANDWIDTH_TOTAL").reset_index()
median = median.sort_values(by ='BANDWIDTH_TOTAL').reset_index()

# %%
sum_all = data.groupby("SERVER_NAME").BANDWIDTH_TOTAL.sum().reset_index()
sum_all = sum_all.sort_values(by = 'BANDWIDTH_TOTAL').reset_index()

# %%
mean['log'] = np.log(mean.BANDWIDTH_TOTAL)
median['log'] = np.log(median.BANDWIDTH_TOTAL)

# %%
del mean['index']
del median['index']

# %%
sum_all = data.groupby("SERVER_NAME").sum()

# %%
iplot(sum_all.iplot(kind = 'scatter', mode= 'markers', asFigure=True, y = 'BANDWIDTH_TOTAL', size= 4))
# Out:
# <div id="624f4eb8-d7d5-4a40-94b4-d485e79ba74b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("624f4eb8-d7d5-4a40-94b4-d485e79ba74b")) {
# ...

# %%
iplot(maximum.iplot(kind = 'scatter', mode= 'markers', asFigure=True, y = 'BANDWIDTH_TOTAL', size= 4))
# Out:
# <div id="a1a4d98c-3daa-463b-918f-7595a83e5c6c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a1a4d98c-3daa-463b-918f-7595a83e5c6c")) {
# ...

# %%
minimum['exp'] = np.exp(minimum.BANDWIDTH_TOTAL)

# %%
data = data[data.SERVER_NAME != 'SERVER_ZONE03_057']

# %%
minimum.sort_values(by = 'exp').reset_index(inplace)

# %%
minimum.reset_index(inplace = True)

# %%
data.head()
# Out:
#   UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 0  2017-10-01        0    ZONE01  SERVER_ZONE01_001        26.906932
# 1  2017-10-01        0    ZONE01  SERVER_ZONE01_002        61.481693
# 2  2017-10-01        0    ZONE01  SERVER_ZONE01_003        20.609837
# 3  2017-10-01        0    ZONE01  SERVER_ZONE01_004        97.737384
# 4  2017-10-01        0    ZONE01  SERVER_ZONE01_005       113.250685
#
#    MAX_USER  is_redundant
# 0     612.0         False
# 1     561.0         False
# 2     969.0         False
# 3    1377.0         False
# 4    1887.0         False

# %%
data.BANDWIDTH_TOTAL.maxAND
# Out:
# 1997.152450909091

# %%
import numpy as np

arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([1,2])

# %%
arr1*arr2
# Out:
# array([[1, 4],
#        [3, 8]])

# %%
print(arr1)
print(arr2)
# Out:
# [[1 2]
#  [3 4]]
# [1 2]

# %%
mask = (data.SERVER_NAME== 'SERVER_ZONE02_095')&((data.BANDWIDTH_TOTAL== 0))
data[mask]
# Out:
#         UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 583346   2017-12-09        3    ZONE02  SERVER_ZONE02_095              0.0
# 584348   2017-12-09        5    ZONE02  SERVER_ZONE02_095              0.0
# 591362   2017-12-09       19    ZONE02  SERVER_ZONE02_095              0.0
# 591863   2017-12-09       20    ZONE02  SERVER_ZONE02_095              0.0
# 592865   2017-12-09       22    ZONE02  SERVER_ZONE02_095              0.0
# 593867   2017-12-10        0    ZONE02  SERVER_ZONE02_095              0.0
# 594869   2017-12-10        2    ZONE02  SERVER_ZONE02_095              0.0
# 595370   2017-12-10        3    ZONE02  SERVER_ZONE02_095              0.0
# 595871   2017-12-10        4    ZONE02  SERVER_ZONE02_095              0.0
# 596372   2017-12-10        5    ZONE02  SERVER_ZONE02_095              0.0
# 605390   2017-12-10       23    ZONE02  SERVER_ZONE02_095              0.0
# ...

# %%
data[data.BANDWIDTH_TOTAL < 0.01 ].BANDWIDTH_TOTAL.value_counts()
# Out:
# 0.000000    8835
# 0.000007     375
# 0.000009     222
# 0.000004     196
# 0.000005     156
# 0.000015     145
# 0.000008     135
# 0.000013     123
# 0.000011     121
# 0.000019     113
# 0.000020      87
# 0.000022      87
# 0.000025      84
# 0.000024      77
# 0.000029      74
# 0.000015      67
# 0.000026      66
# 0.000028      63
# 0.000016      61
# 0.000030      57
# 0.000039      55
# 0.000031      54
# 0.000067      52
# 0.000025      50
# 0.000044      49
# 0.000012      48
# 0.000023      47
# 0.000033      46
# 0.000065      45
# 0.000018      45
#             ...
# 0.003596       1
# 0.003113       1
# 0.002420       1
# 0.003908       1
# 0.008543       1
# 0.005587       1
# 0.007544       1
# 0.006586       1
# 0.007228       1
# 0.003951       1
# 0.002102       1
# 0.009535       1
# 0.009418       1
# 0.005624       1
# 0.008892       1
# 0.004548       1
# 0.009814       1
# 0.001696       1
# 0.008576       1
# 0.003286       1
# 0.008625       1
# ...

# %%
server1.BANDWIDTH_TOTAL.hist(bins=50)

# %%
iplot(minimum.iplot(kind = 'scatter', mode= 'markers', asFigure=True, y = 'exp', size= 4))
# Out:
# <div id="038792ab-14b3-4c23-b886-33c6dd7be70d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("038792ab-14b3-4c23-b886-33c6dd7be70d")) {
# ...

# %%
iplot(median.iplot(kind = 'scatter', mode= 'markers', asFigure=True, y = 'log', size= 4))
# Out:
# <div id="7769d00a-a9c8-40a0-ade9-6d080af47fa2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("7769d00a-a9c8-40a0-ade9-6d080af47fa2")) {
# ...

# %%
pd.to_datetime('2017-10-01 00', format = '%Y-%m-%d %H')
# Out:
# Timestamp('2017-10-01 00:00:00')

# %%
def zero_pad(num):
    return '{:02d}'.format(num)

zero_pad = np.vectorize(zero_pad)

# %%
data['TIME'] = pd.to_datetime(data.UPDATE_TIME + ' ' + zero_pad(data.HOUR_ID), format = '%Y-%m-%d %H')

# %%
mask = (data.SERVER_NAME == 'SERVER_ZONE01_001') & (data.HOUR_ID == 3)
iplot(data[mask].iplot(x='TIME',y = 'BANDWIDTH_TOTAL', asFigure=True))
# Out:
# <div id="c55343ad-5650-4ccd-a344-cda17b843a3a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("c55343ad-5650-4ccd-a344-cda17b843a3a")) {
# ...

# %%
data.shape
# Out:
# (6017583, 7)

# %%
median = data.groupby(['SERVER_NAME','HOUR_ID']).BANDWIDTH_TOTAL.median().reset_index()

# %%
mean = data.groupby(['SERVER_NAME','HOUR_ID']).BANDWIDTH_TOTAL.mean().reset_index()

# %%
median.shape
# Out:
# (13617, 3)

# %%
median[median.BANDWIDTH_TOTAL < 1]
# Out:
#              SERVER_NAME  HOUR_ID  BANDWIDTH_TOTAL
# 507    SERVER_ZONE01_022        3         0.888344
# 1081   SERVER_ZONE01_046        1         0.446190
# 1082   SERVER_ZONE01_046        2         0.214163
# 1083   SERVER_ZONE01_046        3         0.155912
# 1084   SERVER_ZONE01_046        4         0.235022
# 1611   SERVER_ZONE01_068        3         0.842974
# 1659   SERVER_ZONE01_070        3         0.688648
# 1660   SERVER_ZONE01_070        4         0.909583
# 1705   SERVER_ZONE01_072        1         0.514410
# 1706   SERVER_ZONE01_072        2         0.187409
# 1707   SERVER_ZONE01_072        3         0.152879
# 1708   SERVER_ZONE01_072        4         0.169133
# 1709   SERVER_ZONE01_072        5         0.399480
# 1754   SERVER_ZONE01_074        2         0.814080
# 1755   SERVER_ZONE01_074        3         0.568710
# 1756   SERVER_ZONE01_074        4         0.707004
# 1850   SERVER_ZONE01_078        2         0.778409
# ...

# %%
# %matplotlib inline
np.log((data.MAX_USER + 1)).hist(bins = 50)

# %%
data = data[(data.BANDWIDTH_TOTAL != 0)&(data.MAX_USER !=0)]

# %%
del cleaned_data

# %%
max(data.MAX_USER)
# Out:
# 43656.0

# %%
data.UPDATE_TIME = pd.to_datetime(data.UPDATE_TIME)

# %%
data['dow'] = data.UPDATE_TIME.dt.dayofweek

# %%
print(data[data.UPDATE_TIME == '2018-08-13'].SERVER_NAME.nunique())
print(data[data.UPDATE_TIME == '2018-08-15'].SERVER_NAME.nunique())
# Out:
# 515
# 515

# %%
data[data.UPDATE_TIME == '2018-08-14'].SERVER_NAME.nunique()
# Out:
# 515

# %%
d1 = pd.to_datetime('26-12-2017')
d2 = pd.to_datetime('17-04-2018')
d3 = pd.to_datetime('14-08-2018')
d4 = pd.to_datetime('12-12-2018')

# %%
print(d2-d1)
print(d3-d2)
print(d4-d3)
# Out:
# 112 days 00:00:00
# 119 days 00:00:00
# 120 days 00:00:00

# %%
set()

# %%
iplot(data[data.SERVER_NAME == 'SERVER_ZONE01_002'][data.HOUR_ID==21][data.dow == 1].groupby('UPDATE_TIME').BANDWIDTH_TOTAL.sum().iplot(asFigure = True))
# Out:
# /home/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# <div id="999485f5-4c05-459f-a1f7-c6b392ac4153" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("999485f5-4c05-459f-a1f7-c6b392ac4153")) {
# ...

# %%
data.head()
# Out:
#   UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 0  2017-10-01        0    ZONE01  SERVER_ZONE01_001        26.906932
# 1  2017-10-01        0    ZONE01  SERVER_ZONE01_002        61.481693
# 2  2017-10-01        0    ZONE01  SERVER_ZONE01_003        20.609837
# 3  2017-10-01        0    ZONE01  SERVER_ZONE01_004        97.737384
# 4  2017-10-01        0    ZONE01  SERVER_ZONE01_005       113.250685
#
#    MAX_USER  dow
# 0     612.0    6
# 1     561.0    6
# 2     969.0    6
# 3    1377.0    6
# 4    1887.0    6

# %%
temp = data.groupby("SERVER_NAME").BANDWIDTH_TOTAL.sum().reset_index

# %%
temp.sort_values(by = 'BANDWIDTH_TOTAL', ascending=False)
# Out:
#            SERVER_NAME  BANDWIDTH_TOTAL
# 325  SERVER_ZONE01_327     6.375777e+06
# 191  SERVER_ZONE01_192     4.985370e+06
# 17   SERVER_ZONE01_018     4.614612e+06
# 127  SERVER_ZONE01_128     4.089794e+06
# 130  SERVER_ZONE01_131     3.912505e+06
# 170  SERVER_ZONE01_171     3.755995e+06
# 4    SERVER_ZONE01_005     3.721761e+06
# 335  SERVER_ZONE01_337     3.442020e+06
# 360  SERVER_ZONE01_362     3.309854e+06
# 316  SERVER_ZONE01_318     3.245326e+06
# 324  SERVER_ZONE01_326     3.223706e+06
# 51   SERVER_ZONE01_052     3.164691e+06
# 54   SERVER_ZONE01_055     3.154106e+06
# 180  SERVER_ZONE01_181     3.112177e+06
# 303  SERVER_ZONE01_305     3.078468e+06
# 113  SERVER_ZONE01_114     3.076284e+06
# 305  SERVER_ZONE01_307     3.028813e+06
# 76   SERVER_ZONE01_077     2.919397e+06
# 314  SERVER_ZONE01_316     2.908370e+06
# 209  SERVER_ZONE01_211     2.896057e+06
# 44   SERVER_ZONE01_045     2.869850e+06
# 247  SERVER_ZONE01_249     2.837799e+06
# ...

# %%
iplot(data.groupby('UPDATE_TIME').BANDWIDTH_TOTAL.sum().iplot(asFigure = True))
# Out:
# <div id="a7ea9b68-0fea-4944-9315-1d7706661ad3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a7ea9b68-0fea-4944-9315-1d7706661ad3")) {
# ...

# %%
len(set(data.MAX_USER/51))
# Out:
# 505

# %%
len(set(data.BANDWIDTH_TOTAL))
# Out:
# 5908553

# %%
data.MAX_USER

# %%
(data.BANDWIDTH_TOTAL).describe()
# Out:
# count    6.252987e+06
# mean     9.168851e+01
# std      1.296159e+02
# min      3.636364e-06
# 25%      1.107088e+01
# 50%      4.424547e+01
# 75%      1.184026e+02
# max      2.719886e+03
# Name: BANDWIDTH_TOTAL, dtype: float64

# %%
data.MAX_USER.max()
# Out:
# 43656.0

# %%
np.log(data.BANDWIDTH_TOTAL).hist()

# %%
np.log(data.MAX_USER/51).hist()

# %%
iplot(data[(data.SERVER_NAME == 'SERVER_ZONE01_371')&(data.HOUR_ID==0)].iplot(asFigure = True, x='UPDATE_TIME', y = "MAX_USER"))
# Out:
# <div id="32ad54a9-4c91-4f9f-a975-0e918db3d160" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("32ad54a9-4c91-4f9f-a975-0e918db3d160")) {
# ...

# %%
data[(data.MAX_USER == 0) & (data.BANDWIDTH_TOTAL ==0)]
# Out:
#         UPDATE_TIME  HOUR_ID ZONE_CODE        SERVER_NAME  BANDWIDTH_TOTAL  \
# 505      2017-10-01        1    ZONE01  SERVER_ZONE01_225              0.0
# 818      2017-10-01        2    ZONE01  SERVER_ZONE01_225              0.0
# 1131     2017-10-01        3    ZONE01  SERVER_ZONE01_225              0.0
# 15947    2017-10-03        2    ZONE01  SERVER_ZONE01_365              0.0
# 30497    2017-10-05        1    ZONE01  SERVER_ZONE01_170              0.0
# 38369    2017-10-06        2    ZONE01  SERVER_ZONE01_225              0.0
# 38680    2017-10-06        3    ZONE01  SERVER_ZONE01_223              0.0
# 38682    2017-10-06        3    ZONE01  SERVER_ZONE01_225              0.0
# 60590    2017-10-09        1    ZONE01  SERVER_ZONE01_223              0.0
# 60905    2017-10-09        2    ZONE01  SERVER_ZONE01_225              0.0
# 91073    2017-10-13        2    ZONE01  SERVER_ZONE01_371              0.0
# ...

# %%
data.describe()
# Out:
#             HOUR_ID  BANDWIDTH_TOTAL      MAX_USER
# count  6.264394e+06     6.264394e+06  6.264394e+06
# mean   1.149958e+01     9.152155e+01  1.221791e+03
# std    6.914619e+00     1.295568e+02  1.368557e+03
# min    0.000000e+00     0.000000e+00  0.000000e+00
# 25%    6.000000e+00     1.095481e+01  4.080000e+02
# 50%    1.200000e+01     4.407656e+01  7.650000e+02
# 75%    1.700000e+01     1.181855e+02  1.479000e+03
# max    2.300000e+01     2.719886e+03  4.365600e+04

# %% [markdown]
# ## Num servers by date

# %%
iplot(data.groupby('UPDATE_TIME').SERVER_NAME.nunique().iplot(asFigure = True))
# Out:
# <div id="e80fceef-6fcf-4b7a-b75c-8542a45f7304" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("e80fceef-6fcf-4b7a-b75c-8542a45f7304")) {
# ...

# %%
iplot(test.groupby('UPDATE_TIME').SERVER_NAME.nunique().iplot(asFigure = True))
# Out:
# <div id="3689eacb-e43a-4734-80c4-91f0e13ed00e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("3689eacb-e43a-4734-80c4-91f0e13ed00e")) {
# ...

# %%
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
iplot(num_server_by_date.iplot(asFigure=True))
# Out:
# <div id="0b015e8e-54ca-4b30-a2ab-0a6d02ab4c52" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("0b015e8e-54ca-4b30-a2ab-0a6d02ab4c52")) {
# ...

# %%
data[['BANDWIDTH_TOTAL','MAX_USER']].plot(kind='scatter', x='BANDWIDTH_TOTAL', y = 'MAX_USER')

# %%
temp = data[(data.SERVER_NAME == 'SERVER_ZONE01_016')].groupby("UPDATE_TIME").BANDWIDTH_TOTAL.sum().reset_index()
iplot(temp.iplot(asFigure = True, x= 'UPDATE_TIME',y='BANDWIDTH_TOTAL'))
# Out:
# <div id="6f95e144-89f2-4cff-aa69-b4f02553cb14" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6f95e144-89f2-4cff-aa69-b4f02553cb14")) {
# ...

# %%
available_servers = set(data['SERVER_NAME'])

# %%
len(available_servers)
# Out:
# 568

# %%
iplot(data.groupby('UPDATE_TIME').ZONE_CODE.nunique().iplot(asFigure=True))
# Out:
# <div id="510b90de-ab92-46a3-aea5-0f3192f04f5e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("510b90de-ab92-46a3-aea5-0f3192f04f5e")) {
# ...

# %%
iplot(data.groupby('UPDATE_TIME').SERVER_NAME.nunique().iplot(asFigure=True))
# Out:
# <div id="17379dfa-efe8-453d-a4ea-2728675fca11" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("17379dfa-efe8-453d-a4ea-2728675fca11")) {
# ...

# %%
data[data.UPDATE_TIME == '2018-02-27'].MAX_USER.sum()
# Out:
# 10059903.0

# %%
iplot(temp.iplot(asFigure= True, x='UPDATE_TIME', y="N"))
# Out:
# <div id="e5865c56-4596-4434-8210-b0c807c2000d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("e5865c56-4596-4434-8210-b0c807c2000d")) {
# ...

# %%
test = pd.read_csv("./datasets/test_id.csv")

# %%
iplot(test.groupby('UPDATE_TIME').SERVER_NAME.nunique().iplot(asFigure =True))
# Out:
# <div id="63e7609a-24a1-448e-8af0-d81b8d648922" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("63e7609a-24a1-448e-8af0-d81b8d648922")) {
# ...

# %%
import numpy as np

# %%
data = np.random.exponential(3,100)

# %%
from scipy.optimize import minimize

# %%
from functools import partial

# %%
mape_ = partial(mape, targ= data)

# %%
res =minimize(mape_, 1)

# %%
res['x'][0]
# Out:
# 2.134749993337205

# %%
mapes = []
preds = []
for i in np.linspace(1, 3, 1000):
    mapes.append(mape(i, data))
    preds.append(i)

# %%
np.argmin(mapes)
# Out:
# 567

# %%
preds[567]
# Out:
# 2.135135135135135

# %%
mapes[567]
# Out:
# 45.755714874278866

# %%
np.median(1/data)
# Out:
# 0.3296369137572904

# %%
# Out:
# 64.10872149644504

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot(preds, mapes, 'r-',)

# %%
np.argmin(mapes)
# Out:
# 309

# %%
mapes[309]
# Out:
# 90.69926159938704

# %%
preds[309]
# Out:
# 0.30930930930930933

# %%
print(mapes[16])
print(mape(0.38422556957768295, data))
# Out:
# 90.7165159964344
# 91.57081674455733

# %%
np.median(1/data)
# Out:
# 0.38422556957768295
